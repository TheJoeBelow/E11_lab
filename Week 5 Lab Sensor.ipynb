# %%
import numpy as np
import math
import pandas as pd
# This line allows plots to show in the Jupyter notebook
# %matplotlib inline
import matplotlib.pyplot as plt
import io
import requests

# %%
data = pd.read_csv('sensor_data.csv')

# %%
#print(data)

# %%
temp_data = data.loc[:,"Temperature":"Time"]
print(temp_data)
# Out:
#     Temperature  Humidity  Pressure  PM1  PM2.5  PM10          Time
# 0         22.01     56.48   1002.13    3      4     6  1.630716e+09
# 1         22.01     56.46   1002.07    3      4     6  1.630716e+09
# 2         22.01     56.54   1002.08    3      4     6  1.630716e+09
# 3         22.02     56.53   1002.09    3      4     6  1.630716e+09
# 4         22.01     56.73   1002.08    3      4     6  1.630716e+09
# 5         22.06     59.04   1002.11    3      4     6  1.630716e+09
# 6         22.12     60.42   1002.10    3      4     6  1.630716e+09
# 7         22.14     60.05   1002.13    3      4     6  1.630716e+09
# 8         22.17     59.86   1002.08    3      4     6  1.630716e+09
# 9         22.22     61.17   1002.14    3      4     6  1.630716e+09
# 10        23.74     79.20   1002.13    3      4     6  1.630716e+09
# 11        23.74     84.06   1002.16    3      4     6  1.630716e+09
# 12        23.06     84.33   1002.13    3      4     6  1.630716e+09
# 13        22.99     85.43   1002.12    3      4     6  1.630716e+09
# 14        22.99     86.04   1002.10    3      4     6  1.630716e+09
# 15        22.89     86.06   1002.11    3      4     6  1.630716e+09
# 16        22.77     85.71   1002.14    3      4     6  1.630716e+09
# 17        22.56     82.57   1002.71    3      4     6  1.630716e+09
# 18        22.87     80.80   1002.07    3      4     6  1.630716e+09
# 19        22.92     72.13   1002.28    3      4     6  1.630716e+09
# 20        23.15     74.53   1002.15    3      4     6  1.630716e+09
# 21        23.11     67.34   1002.08    3      4     6  1.630716e+09
# 22        23.24     70.82   1002.12    3      4     6  1.630716e+09
# 23        23.34     72.02   1002.14    3      4     6  1.630716e+09
# 24        23.32     68.83   1002.13    3      4     6  1.630716e+09
# 25        23.31     65.45   1002.11    3      4     6  1.630716e+09
# 26        24.31     79.69   1002.16    3      4     6  1.630716e+09
# 27        25.30     88.42   1002.14    3      4     6  1.630716e+09

# %%
plt.plot(temp_data['Temperature'])
plt.ylabel('Temperature (C)') # label the y-axis
plt.xlabel('Time (s)')
plt.title("CPM vs index")                                  # put a title!
plt.show()

# %%
plt.plot(temp_data['Humidity'])
plt.ylabel('Humidity (gH20/kg air)') # label the y-axis
plt.xlabel('Time (s)')
plt.title("CPM vs index")                                  # put a title!
plt.show()

# %%
plt.plot(temp_data['Pressure'])
plt.ylabel('Pressure (hPa)')
plt.xlabel('Time (s)')
plt.title("CPM vs index")                                  
plt.show()
